# %%
import pandas as pd
import mod_sql

# %%
import imp
imp.reload(mod_sql)
# Out:
# <module 'mod_sql' from 'c:\\ubion\\061522\\mod_sql\\__init__.py'>

# %%
## mod_sql 모듈을 사용해서 class Database 선언

_db = mod_sql.Database()

# %%
sql = """SELECT * from test""" 

## Database 클래스 안에서 결과값을 받아오는 함수 -> executeAll() 결과값을 return

_db.executeAll(sql)
# Out:
#    No      ID password  name        phone
# 0   1    test     4321  moon  01012345678
# 1   3   test1     0000  choi  01039348786
# 2   4   test2     1234   kim  01089896767
# 3   6   test4     4321   kim  01089896767
# 4   7  test10     0123  park  01095676543

# %%
sql = """INSERT into test(id, password, name, phone) values(%s, %s, %s, %s)"""

values = ["test10", "0123", "park", "01095676543"]

_db.execute(sql, values)

# %%
_db.commit()

# %%
sql = """ SELECT * from sales """

_db.executeAll(sql)
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
sql = """SELECT `Item Type` from sales"""

_db.executeAll(sql)
# Out:
#             Item Type
# 0     Office Supplies
# 1           Beverages
# 2          Vegetables
# 3           Household
# 4           Beverages
# ...               ...
# 9995        Beverages
# 9996        Cosmetics
# 9997       Vegetables
# 9998             Meat
# 9999           Snacks
#
# [10000 rows x 1 columns]

# %%
sql = """ 
SELECT Country, 
AVG(`Units Sold`) as avg, 
COUNT(`Units Sold`) as cnt,
SUM(`Units Sold`) as sum
from sales
group by Country
"""

_db.executeAll(sql)
# Out:
#                               Country        avg  cnt     sum
# 0                                Chad  5411.9796   49  265187
# 1                              Latvia  4501.1522   46  207053
# 2                            Pakistan  5038.5556   45  226735
# 3    Democratic Republic of the Congo  5067.8500   60  304071
# 4                      Czech Republic  5437.6383   47  255569
# ..                                ...        ...  ...     ...
# 180                            Jordan  4897.3636   55  269355
# 181                     Guinea-Bissau  5282.0926   54  285233
# 182                           Bahrain  5506.7500   64  352432
# 183                     Cote d'Ivoire  4496.2045   44  197833
# 184                          Malaysia  4652.4615   52  241928
#
# [185 rows x 4 columns]

# %%
sql = """ 
SELECT
distinct(Region) as region
from sales
"""

_db.executeAll(sql)
# Out:
#                               region
# 0                 Sub-Saharan Africa
# 1                             Europe
# 2       Middle East and North Africa
# 3                               Asia
# 4  Central America and the Caribbean
# 5              Australia and Oceania
# 6                      North America
